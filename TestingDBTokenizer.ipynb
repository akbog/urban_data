# %% [markdown]
# ## Testing the Preprocessor (Tokenizer, Lemmatization, Stop-word removal, replacement text etc.)

# %%
from Modules.NewDatabaseProcessor import DatabasePreprocessor
from sqlalchemy import create_engine
from Modules.models import *
import pandas as pd

# %%
database_url = "postgres+psycopg2://bogdanowicz:urbandata@localhost:5432/twitter"
db_prep = DatabasePreprocessor(database_url)

# %%
len(list(db_prep.transform()))
# Out:
# 17

# %%
engine = create_engine(database_url)
tokenized_tweets = pd.read_sql("tweet", engine)

# %%
tokenized_tweets
# Out:
#                         id              user_id             created  \
# 0      1245152891536429056            131549924 2020-04-01 00:55:57
# 1      1245115838899851268            541528596 2020-03-31 22:28:43
# 2      1245115847011696648  1107966692922220545 2020-03-31 22:28:45
# 3      1245115864329773056            108818446 2020-03-31 22:28:49
# 4      1245115872483504128  1243582443380072448 2020-03-31 22:28:51
# ...                    ...                  ...                 ...
# 16129  1245153168276639744  1224809296799485952 2020-04-01 00:57:03
# 16130  1245153168293367808            872343469 2020-04-01 00:57:03
# 16131  1244329080482410498             19084896 2020-03-29 18:22:25
# 16132  1244320570315018240             25073877 2020-03-29 17:48:36
# 16133  1245153168410861568  1036268097533964288 2020-04-01 00:57:03
#
#                                                full_text  reply_id  \
# 0                                                 R.I.P.       NaN
# ...

# %%
#Works great
